# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# Out:
# /content/gdrive/My Drive

# %%
# %cd Colab\ Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/.git/

# %%
# !git remote rm origin

# %%
# !git remote add origin https://Tishran:Twtdtyf2004@github.com/Tishran/SchoolProject.git

# %%
# !git remote -v
# Out:
# origin	https://Tishran:Twtdtyf2004@github.com/Tishran/SchoolProject.git (fetch)
# origin	https://Tishran:Twtdtyf2004@github.com/Tishran/SchoolProject.git (push)

# %%
# !git config --global user.email 'rushan.hamatyrov@mail.ru'
# !git config --global user.name 'Tishran'

# %%
# !git add .

# %%
# !git commit -m 'First commit with simpletransformers'
# Out:
# [master (root-commit) 5d50a4b] First commit with simpletransformers
#  4 files changed, 4 insertions(+)
#  create mode 100644 JustEmbeds.ipynb
#  create mode 100644 SomeCodeForProject.ipynb
#  create mode 100644 Untitled
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://Tishran:Twtdtyf2004@github.com/Tishran/SchoolProject.git/'
